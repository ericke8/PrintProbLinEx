# %%
import cv2 as cv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
img = cv.imread("anon_blank_blank_00height_amaske-6913_page1r.tif", 0)

sol_rows = pd.read_csv("anon_blank_blank_00height_amaske-6913_page1r_splits.csv", header=None, names=["row"])
split = sol_rows["row"]
for row in range(0,split.shape[0] - 1):
    cutLine = img[split[row]:split[row+1],:]
    plt.imshow(cutLine, cmap="gray")
    plt.show()
