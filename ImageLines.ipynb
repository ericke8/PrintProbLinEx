# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
rows = pd.read_csv("anon_blank_blank_00height_amaske-6914_page1r_lines.csv", header=None, names=["start", "end"])
print(rows)
print(rows.shape)
# Out:
#     start   end
# 0      47   100
# 1      94   147
# 2     140   193
# 3     186   239
# 4     232   285
# 5     278   331
# 6     325   378
# 7     371   424
# 8     417   470
# 9     462   515
# 10    509   562
# 11    555   608
# 12    601   654
# 13    647   700
# 14    693   746
# 15    786   839
# 16    832   885
# 17    877   930
# 18    923   976
# 19    969  1022
# 20   1015  1068
# 21   1108  1161
# 22   1154  1207
# 23   1200  1253
# 24   1246  1299
# 25   1293  1346
# 26   1339  1392
# 27   1385  1438
# (28, 2)

# %%
document = cv.imread("anon_blank_blank_00height_amaske-6914_page1r.tif")
plt.imshow(document)
plt.show()

# %%
print(rows.loc[0])
# Out:
# start     47
# end      100
# Name: 0, dtype: int64

# %%
print(rows.shape)
# Out:
# (28, 2)

# %%
for row in range(0,rows.shape[0]): #rows.shape[0]
    rowHeight = rows.loc[row].end - rows.loc[row].start
    print(rowHeight)
    cutLine = document[rows.loc[row].start:rows.loc[row].end,:]
    plt.imshow(cutLine)
    plt.show()
# Out:
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53

# %%
lines3 = pd.read_csv("explore_lines3.csv", header=None, names=["start"])
print(lines3.head())
# Out:
#    start
# 0     20
# 1     66
# 2    112
# 3    158
# 4    204

# %%
lines4 = pd.read_csv("explore_lines4.csv", header=None, names=["start"])
print(lines4.head())
# Out:
#    start
# 0     17
# 1     63
# 2     63
# 3    109
# 4    109

# %%
lines5 = pd.read_csv("explore_lines5.csv", header=None, names=["start","end"])
print(lines5.head())
# Out:
#    start  end
# 0     17   63
# 1     63  109
# 2    109  155
# 3    156  202
# 4    202  248
