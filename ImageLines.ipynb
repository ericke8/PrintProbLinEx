# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
rows = pd.read_csv("anon_blank_blank_00height_amaske-6912_page1r_lines.csv", header=None, names=["start", "end"])
print(rows)
print(rows.shape)
# Out:
#     start   end
# 0      16    63
# 1      62   109
# 2     108   155
# 3     155   202
# 4     201   248
# 5     247   294
# 6     294   341
# 7     340   387
# 8     386   433
# 9     432   479
# 10    478   525
# 11    525   572
# 12    571   618
# 13    617   664
# 14    663   710
# 15    709   756
# 16    755   802
# 17    801   848
# 18    846   893
# 19    893   940
# 20    939   986
# 21    985  1032
# 22   1030  1077
# 23   1077  1124
# 24   1123  1170
# 25   1169  1216
# 26   1215  1262
# 27   1262  1309
# 28   1308  1355
# 29   1354  1401
# 30   1400  1447
# (31, 2)

# %%
document = cv.imread("anon_blank_blank_00height_amaske-6912_page1r.tif")
plt.imshow(document)
plt.show()

# %%
print(rows.loc[0])
# Out:
# start    16
# end      63
# Name: 0, dtype: int64

# %%
print(rows.shape)
# Out:
# (31, 2)

# %%
for row in range(0,rows.shape[0]): #rows.shape[0]
    rowHeight = rows.loc[row].end - rows.loc[row].start
    print(rowHeight)
    cutLine = document[rows.loc[row].start:rows.loc[row].end,:]
    plt.imshow(cutLine)
    plt.show()
# Out:
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47

# %%
lines3 = pd.read_csv("explore_lines3.csv", header=None, names=["start"])
print(lines3.head())
# Out:
#    start
# 0     20
# 1     66
# 2    112
# 3    158
# 4    204

# %%
lines4 = pd.read_csv("explore_lines4.csv", header=None, names=["start"])
print(lines4.head())
# Out:
#    start
# 0     17
# 1     63
# 2     63
# 3    109
# 4    109

# %%
lines5 = pd.read_csv("explore_lines5.csv", header=None, names=["start","end"])
print(lines5.head())
# Out:
#    start  end
# 0     17   63
# 1     63  109
# 2    109  155
# 3    156  202
# 4    202  248
